# %%
from concurrent.futures import ThreadPoolExecutor, ProcessPoolExecutor
    
def execute_parallel(parameter):
    parameter_dict = {
        "fecha_inicio" : parameter[0],
        "fecha_final" : parameter[1],
    }
    
    return dbutils.notebook.run(path = "/Users/matgaoga@efectivo.com.co/Historico NLP- MG",
                                timeout_seconds = 9000, 
                                 arguments = parameter_dict)
        
max_workers = 2 #Numero maximo notebooks paralelo
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
parameters=[]

#funcion aplicada es between (incluye los extremos)

lista_base = ['2022-02-15','2022-02-16']  #INICIO INCLUYE, FINAL NO INCLUYE
parameters.append(lista_base)

lista_base = ['2022-02-14','2022-02-15']
parameters.append(lista_base)

# lista_base = ['2022-02-05','2022-02-08']
# parameters.append(lista_base)


with ThreadPoolExecutor(max_workers = max_workers) as executor:
    results = executor.map(execute_parallel, parameters)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
